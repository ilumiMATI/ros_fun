# %%
# !rosrun turtlesim turtlesim_node
# Out:
# QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-ubuntu'
# [ INFO] [1625488358.081828000]: Starting turtlesim with node name /turtlesim
# [ INFO] [1625488358.109422500]: Spawning turtle [turtle1] at x=[5.544445], y=[5.544445], theta=[0.000000]
# [ WARN] [1625488453.536264000]: Oh no! I hit the wall! (Clamping from [x=11.089602, y=7.425788])
# [ WARN] [1625488453.552598300]: Oh no! I hit the wall! (Clamping from [x=11.113577, y=7.405429])
# [ WARN] [1625488453.568050400]: Oh no! I hit the wall! (Clamping from [x=11.112572, y=7.383909])
# [ WARN] [1625488453.589656000]: Oh no! I hit the wall! (Clamping from [x=11.111512, y=7.361277])
# [ WARN] [1625488453.620584900]: Oh no! I hit the wall! (Clamping from [x=11.110400, y=7.337585])
# [ WARN] [1625488453.637374000]: Oh no! I hit the wall! (Clamping from [x=11.109238, y=7.312889])
# [ WARN] [1625488453.653694700]: Oh no! I hit the wall! (Clamping from [x=11.108030, y=7.287245])
# ...
