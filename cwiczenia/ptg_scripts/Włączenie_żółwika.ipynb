# %%
# !rosrun turtlesim turtlesim_node
# Out:
# QStandardPaths: XDG_RUNTIME_DIR not set, defaulting to '/tmp/runtime-ubuntu'
# [ INFO] [1625348059.606223400]: Starting turtlesim with node name /turtlesim
# [ INFO] [1625348059.615620000]: Spawning turtle [turtle1] at x=[5.544445], y=[5.544445], theta=[0.000000]
# [ INFO] [1625348868.486095200]: Resetting turtlesim.
# [ INFO] [1625348868.530090500]: Spawning turtle [turtle1] at x=[5.544445], y=[5.544445], theta=[0.000000]
# [ INFO] [1625349047.807154400]: Spawning turtle [Danonek4] at x=[4.000000], y=[1.000000], theta=[0.000000]
# [ INFO] [1625349107.562245000]: Resetting turtlesim.
# [ INFO] [1625349107.581911200]: Spawning turtle [turtle1] at x=[5.544445], y=[5.544445], theta=[0.000000]
# [ INFO] [1625349202.661118800]: Spawning turtle [Danonek4] at x=[4.000000], y=[1.000000], theta=[0.000000]
# [ INFO] [1625349378.169940800]: Resetting turtlesim.
# [ INFO] [1625349378.235359800]: Spawning turtle [turtle1] at x=[5.544445], y=[5.544445], theta=[0.000000]
# ...
